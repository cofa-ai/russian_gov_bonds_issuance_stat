# %%
from pathlib import Path
import pandas as pd

# %%
ofz_dir = Path('data')
auction_stat_file = ofz_dir / "Rezultaty_12.12.xlsx"

# %%
df = pd.read_excel(auction_stat_file, sheet_name='Лист1', header=1, skiprows=7, skipfooter=2)
df.columns = ["Дата", "Формат", "Код выпуска", "Тип бумаги", "Дата погашения", "Дней до погашения", "Объем предложения", "Цена отсечения",
              "Цена средневзвешенная", "Доходность по цене отсечения", "Доходность по средневзвешенной цене", "Совокупный объем спроса по номиналу", 
              "Объем размещения по номиналу", "Объем выручки", "Коэффициент удовлетворения спроса на аукционе"]
df.tail(10)
# Out:
#            1        2          3       4          5     6            7   \
# 89 2024-11-13  Аукцион  26246RMFS  ОФЗ-ПД 2036-03-12  4137   702998.742
# 90 2024-11-13  Аукцион  26248RMFS  ОФЗ-ПД 2040-05-16  5663   668538.766
# 91 2024-11-13     ДРПА  26248RMFS  ОФЗ-ПД 2040-05-16  5663     7953.372
# 92 2024-11-20  Аукцион  26247RMFS  ОФЗ-ПД 2039-05-11  5285   677736.334
# 93 2024-11-20     ДРПА  26247RMFS  ОФЗ-ПД 2039-05-11  5285    12084.730
# 94 2024-11-27  Аукцион  26245RMFS  ОФЗ-ПД 2035-09-26  3955   458912.739
# 95 2024-12-04  Аукцион  26246RMFS  ОФЗ-ПД 2036-03-12  4116   663154.246
# 96 2024-12-04  Аукцион  29026RMFS  ОФЗ-ПК 2038-09-04  5022  1000000.000
# 97 2024-12-11  Аукцион  29027RMFS  ОФЗ-ПК 2036-09-11  4292  1000000.000
# 98 2024-12-11  Аукцион  26248RMFS  ОФЗ-ПД 2040-05-16  5635   615451.549
#
#          8        9      10     11           12          13             14  \
# 89  78.5401  78.6063  16.84  16.82    65979.237   39844.496   31975.331451
# ...
